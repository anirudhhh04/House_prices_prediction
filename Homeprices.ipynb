# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a074cb4c-feb4-4fcf-9736-1eb80f18ed5f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a074cb4c-feb4-4fcf-9736-1eb80f18ed5f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("pricess.csv")
df
# Out:
#                id  number_of_bedrooms  number_of_bathrooms  living area  \
# 0      6762810145                   5                 2.50         3650
# 1      6762810635                   4                 2.50         2920
# 2      6762810998                   5                 2.75         2910
# 3      6762812605                   4                 2.50         3310
# 4      6762812919                   3                 2.00         2710
# ...           ...                 ...                  ...          ...
# 14615  6762830250                   2                 1.50         1556
# 14616  6762830339                   3                 2.00         1680
# 14617  6762830618                   2                 1.00         1070
# 14618  6762830709                   4                 1.00         1030
# 14619  6762831463                   3                 1.00          900
#
#        lot area    Price
# 0          9050  2380000
# 1          4000  1400000
# ...

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['lot area','number_of_bedrooms','number_of_bathrooms']],df.Price)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([3.84093950e-01, 1.99216579e+04, 2.39915692e+05])

# %%
reg.intercept_
# Out:
# -45107.46491433133

# %%
reg.predict([[3000,3,2]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([495641.17509916])

# %%
reg.predict([[2500,4,5]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1235117.86279857])

# %%
k=int(input("Enter the area:"))
l=int(input("Enter the number of bedrooms:"))
m=int(input("Enter the number of bathrooms:"))
reg.predict([[k,l,m]])
# Out:
# Enter the area:4000
# Enter the number of bedrooms:5
# Enter the number of bathrooms:3
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([775784.27706909])
